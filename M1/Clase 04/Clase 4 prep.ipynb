# %%
import pandas as pd
import numpy as np

# %%
archivo = open(r"C:\Users\salas\OneDrive\Documentos\clasesHenrryModulo1\M1\Clase 02\Emisiones_CO2.csv", encoding='latin-1')
dicc_emisiones = {'cod_pais': [], 
                  'nom_pais': [], 
                  'region': [], 
                  'anio': [], 
                  'co2': [],
                  'co2_percapita': []}
next(archivo)
for linea in archivo:
    linea = linea.strip()
    campos = linea.split('|')
    dicc_emisiones['cod_pais'].append(campos[0])
    dicc_emisiones['nom_pais'].append(campos[1])
    dicc_emisiones['region'].append(campos[2])
    dicc_emisiones['anio'].append(campos[3])
    dicc_emisiones['co2'].append(campos[4])
    dicc_emisiones['co2_percapita'].append(campos[5])
archivo.close()

# %%
lista = list(dict.keys(dicc_emisiones))
lista
# Out:
# ['cod_pais', 'nom_pais', 'region', 'anio', 'co2', 'co2_percapita']

# %%
serie = pd.Series(lista)
serie
# Out:
# 0         cod_pais
# 1         nom_pais
# 2           region
# 3             anio
# 4              co2
# 5    co2_percapita
# dtype: object

# %%
serie = pd.Series({'Java': 5.0, 'Python': 10.0, 'Ruby': 0.0, 'R': 5.0, 'C++': 5.0, 'C': 5.0, 'SQL': 8.0, 'Cobol': np.nan, 'Go': 10.0, 'JavaScript': 10.0})
serie
# Out:
# Java           5.0
# Python        10.0
# Ruby           0.0
# R              5.0
# C++            5.0
# C              5.0
# SQL            8.0
# Cobol          NaN
# Go            10.0
# JavaScript    10.0
# dtype: float64

# %%
serie.size
# Out:
# 10

# %%
serie.index
# Out:
# Index(['Java', 'Python', 'Ruby', 'R', 'C++', 'C', 'SQL', 'Cobol', 'Go',
#        'JavaScript'],
#       dtype='object')

# %%
serie[['Java','Python']]
# Out:
# Java       5.0
# Python    10.0
# dtype: float64

# %%
s = pd.Series(['Matemáticas', 'Historia', 'Economía', 'Programación', 'Inglés'], dtype='string')
#s.index
s[0]
# Out:
# 'Matemáticas'

# %%
serie.dtype
# Out:
# dtype('float64')

# %%
serie[2:5]
# Out:
# Ruby    0.0
# R       5.0
# C++     5.0
# dtype: float64

# %%
print(serie['R'])
print(serie['Python'])
# Out:
# 5.0
# 10.0

# %%
serie
# Out:
# Java           5.0
# Python        10.0
# Ruby           0.0
# R              5.0
# C++            5.0
# C              5.0
# SQL            8.0
# Cobol          NaN
# Go            10.0
# JavaScript    10.0
# dtype: float64

# %%
serie.count()
# Out:
# 9

# %%
serie.sum()
# Out:
# 58.0

# %%
serie.cumsum()
# Out:
# Java           5.0
# Python        15.0
# Ruby          15.0
# R             20.0
# C++           25.0
# C             30.0
# SQL           38.0
# Cobol          NaN
# Go            48.0
# JavaScript    58.0
# dtype: float64

# %%
serie.value_counts()
# Out:
# 5.0     4
# 10.0    3
# 0.0     1
# 8.0     1
# dtype: int64

# %%
serie.min()
# Out:
# 0.0

# %%
serie==0.0
# Out:
# Java          False
# Python        False
# Ruby           True
# R             False
# C++           False
# C             False
# SQL           False
# Cobol         False
# Go            False
# JavaScript    False
# dtype: bool

# %%
serie.max()
# Out:
# 10.0

# %%
serie == 5.0
# Out:
# Java           True
# Python        False
# Ruby          False
# R              True
# C++            True
# C              True
# SQL           False
# Cobol         False
# Go            False
# JavaScript    False
# dtype: bool

# %%
serie.mean()
# Out:
# 6.444444444444445

# %%
serie.std()
# Out:
# 3.3582402799349804

# %%
serie.describe()
# Out:
# count     9.000000
# mean      6.444444
# std       3.358240
# min       0.000000
# 25%       5.000000
# 50%       5.000000
# 75%      10.000000
# max      10.000000
# dtype: float64

# %%
## Count solamente cuenta los valores que no son np.nan ni None

seriesssssss = pd.Series({'Hola': None, 'Chau': np.nan})
seriesssssss.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# dtype: float64

# %%
s = pd.Series([1,2,3,4])
s*2
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
s%2
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# dtype: int64

# %%
s = pd.Series(['a', 'b', 'c'])
s * 5
# Out:
# 0    aaaaa
# 1    bbbbb
# 2    ccccc
# dtype: object

# %%
'a'*5
# Out:
# 'aaaaa'

# %%
## Si sumamos dos tipos de datos distintos, vamos a tener un TypeError
s + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8172\222168938.py in <module>
#       1 ## Si sumamos dos tipos de datos distintos, vamos a tener un TypeError
# ----> 2 s + 1
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\arraylike.py in __add__(self, other)
#      98     @unpack_zerodim_and_defer("__add__")
#      99     def __add__(self, other):
# --> 100         return self._arith_method(other, operator.add)
#     101
#     102     @unpack_zerodim_and_defer("__radd__")
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    5637     def _arith_method(self, other, op):
#    5638         self, other = ops.align_method_SERIES(self, other)
# -> 5639         return base.IndexOpsMixin._arith_method(self, other, op)
#    5640
#    5641
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\base.py in _arith_method(self, other, op)
#    1293
#    1294         with np.errstate(all="ignore"):
# -> 1295             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1296
#    1297         return self._construct_result(result, name=res_name)
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     220         _bool_arith_check(op, left, right)
#     221
# --> 222         res_values = _na_arithmetic_op(left, right, op)
#     223
#     224     return res_values
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     168             # Don't do this for comparisons, as that will handle complex numbers
#     169             #  incorrectly, see GH#32047
# --> 170             result = _masked_arith_op(left, right, op)
#     171         else:
#     172             raise
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _masked_arith_op(x, y, op)
#     125
#     126         if mask.any():
# --> 127             result[mask] = op(xrav[mask], y)
#     128
#     129     np.putmask(result, ~mask, np.nan)
#
# TypeError: can only concatenate str (not "int") to str

# %%
from math import *
s = pd.Series([4,4,5,8,10,1])
s.apply(log)
# Out:
# 0    1.386294
# 1    1.386294
# 2    1.609438
# 3    2.079442
# 4    2.302585
# 5    0.000000
# dtype: float64

# %%
s.apply(sin)
# Out:
# 0   -0.756802
# 1   -0.756802
# 2   -0.958924
# 3    0.989358
# 4   -0.544021
# 5    0.841471
# dtype: float64

# %%
s.apply(cos)
# Out:
# 0   -0.653644
# 1   -0.653644
# 2    0.283662
# 3   -0.145500
# 4   -0.839072
# 5    0.540302
# dtype: float64

# %%
s = pd.Series(['Estamos bien','Hola', 'mundo'])
s.apply(str.upper)
# Out:
# 0    ESTAMOS BIEN
# 1            HOLA
# 2           MUNDO
# dtype: object

# %%
serie
# Out:
# Java           5.0
# Python        10.0
# Ruby           0.0
# R              5.0
# C++            5.0
# C              5.0
# SQL            8.0
# Cobol          NaN
# Go            10.0
# JavaScript    10.0
# dtype: float64

# %%
print(serie[serie>5])
# Out:
# Python        10.0
# SQL            8.0
# Go            10.0
# JavaScript    10.0
# dtype: float64

# %%
print(serie.sort_values())
# Out:
# Ruby           0.0
# Java           5.0
# R              5.0
# C++            5.0
# C              5.0
# SQL            8.0
# Python        10.0
# Go            10.0
# JavaScript    10.0
# Cobol          NaN
# dtype: float64

# %%
print(serie.sort_values(ascending=False))
# Out:
# Python        10.0
# Go            10.0
# JavaScript    10.0
# SQL            8.0
# Java           5.0
# R              5.0
# C++            5.0
# C              5.0
# Ruby           0.0
# Cobol          NaN
# dtype: float64

# %%
## Si son tipo obj los ordena de manera alfabética 
print(serie.sort_index(ascending=False))
# Out:
# SQL            8.0
# Ruby           0.0
# R              5.0
# Python        10.0
# JavaScript    10.0
# Java           5.0
# Go            10.0
# Cobol          NaN
# C++            5.0
# C              5.0
# dtype: float64

# %%
serie

# %%
serie.dropna()
# Out:
# Java           5.0
# Python        10.0
# Ruby           0.0
# R              5.0
# C++            5.0
# C              5.0
# SQL            8.0
# Go            10.0
# JavaScript    10.0
# dtype: float64

# %%
datos = {'nombre':['María', 'Luis', 'Carmen', 'Antonio'],
'edad':[18, 22, 20, 21],'grado':['Economía', 'Medicina', 'Arquitectura', 'Economía'],
'correo':['maria@gmail.com', 'luis@yahoo.es', 'carmen@gmail.com', 'antonio@gmail.com']
}

# %%
df = pd.DataFrame(datos)
df
# Out:
#     nombre  edad         grado             correo
# 0    María    18      Economía    maria@gmail.com
# 1     Luis    22      Medicina      luis@yahoo.es
# 2   Carmen    20  Arquitectura   carmen@gmail.com
# 3  Antonio    21      Economía  antonio@gmail.com

# %%
df = pd.read_csv(r'C:\Users\salas\OneDrive\Documentos\clasesHenrryModulo1\M1\Clase 02\Emisiones_CO2.csv', sep='|', thousands  = ',', encoding= 'ANSI')
df
# Out:
#       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 0                ABW           Aruba  América Latina y Caribe  1960       NaN
# 1                ABW           Aruba  América Latina y Caribe  1961       NaN
# 2                ABW           Aruba  América Latina y Caribe  1962       NaN
# 3                ABW           Aruba  América Latina y Caribe  1963       NaN
# 4                ABW           Aruba  América Latina y Caribe  1964       NaN
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9.732,22
# 11123            ZWE        Zimbabue      África subsahariana  2008  7.682,37
# 11124            ZWE        Zimbabue      África subsahariana  2009  8.239,75
# 11125            ZWE        Zimbabue      África subsahariana  2010  9.028,15
# 11126            ZWE        Zimbabue      África subsahariana  2011  9.860,56
#
#        CO2 per cápita (toneladas métricas)
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 11122                          731866885.0
# 11123                          569255428.0
# 11124                          600521157.0
# 11125                          646072745.0
# 11126                          691697897.0
#
# [11127 rows x 6 columns]

# %%
colesterol = pd.read_csv(r'colesterol.csv', sep=';', decimal=',')
colesterol.describe()
# Out:
#             edad        peso     altura  colesterol
# count  14.000000   13.000000  14.000000   13.000000
# mean   38.214286   70.923077   1.768571  220.230769
# std    15.621379   16.126901   0.115016   39.847948
# min    18.000000   51.000000   1.580000  148.000000
# 25%    24.750000   61.000000   1.705000  194.000000
# 50%    35.000000   65.000000   1.755000  210.000000
# 75%    49.750000   78.000000   1.840000  249.000000
# max    68.000000  109.000000   1.980000  280.000000

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\salas\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\salas\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.DataFrame({'Name': ['María', 'Carlos', 'Carmen'], 'Nacimiento':['05-03-2000', '20-05-2001', '10-12-1999']})
df = pd.to_datetime(df['Nacimiento'], format = '%d-%m-%Y')
#df['Nacimiento'] = df['Nacimiento'].strftime('%d/%m/%Y')
df
# Out:
# 0   2000-03-05
# 1   2001-05-20
# 2   1999-12-10
# Name: Nacimiento, dtype: datetime64[ns]

# %%
rng = pd.date_range(pd.Timestamp("2018-03-10 09:00"),periods=3, freq='s')
rng.strftime('%B %d, %Y, %r')
# Out:
# Index(['March 10, 2018, 09:00:00 AM', 'March 10, 2018, 09:00:01 AM',
#        'March 10, 2018, 09:00:02 AM'],
#       dtype='object')

# %%
colesterol = pd.read_csv(r'colesterol.csv', sep=';' ,decimal=',')
colesterol
# Out:
#                              nombre  edad sexo   peso  altura  colesterol
# 0      José Luis Martínez Izquierdo    18    H   85.0    1.79       182.0
# 1                    Rosa Díaz Díaz    32    M   65.0    1.73       232.0
# 2             Javier García Sánchez    24    H    NaN    1.81       191.0
# 3               Carmen López Pinzón    35    M   65.0    1.70       200.0
# 4              Marisa López Collado    46    M   51.0    1.58       148.0
# 5                 Antonio Ruiz Cruz    68    H   66.0    1.74       249.0
# 6           Antonio Fernández Ocaña    51    H   62.0    1.72       276.0
# 7             Pilar Martín González    22    M   60.0    1.66         NaN
# 8              Pedro Gálvez Tenorio    35    H   90.0    1.94       241.0
# 9           Santiago Reillo Manzano    46    H   75.0    1.85       280.0
# 10            Macarena Álvarez Luna    53    M   55.0    1.62       262.0
# 11       José María de la Guía Sanz    58    H   78.0    1.87       198.0
# 12  Miguel Angel Cuadrado Gutiérrez    27    H  109.0    1.98       210.0
# 13            Carolina Rubio Moreno    20    M   61.0    1.77       194.0

# %%
## probar traer con o sin el indice
csv = pd.read_csv('colesterol.csv', sep=';', index_col=0)
csv
# Out:
#                                  edad sexo   peso altura  colesterol
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0

# %%
## Borrar valores nulos
data = csv.dropna()
data.size
# Out:
# 60

# %%
data
# Out:
#                                  edad sexo   peso altura  colesterol
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0

# %%
data.to_excel('practica_clase4.xlsx')

# %%
csv
# Out:
#                                  edad sexo   peso altura  colesterol
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, José Luis Martínez Izquierdo to Carolina Rubio Moreno
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   edad        14 non-null     int64
#  1   sexo        14 non-null     object
#  2   peso        13 non-null     float64
#  3   altura      14 non-null     object
#  4   colesterol  13 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 672.0+ bytes

# %%
csv.shape
# Out:
# (14, 5)

# %%
csv.size
# Out:
# 70

# %%
csv.columns
# Out:
# Index(['edad', 'sexo', 'peso', 'altura', 'colesterol'], dtype='object')

# %%
csv.index
# Out:
# Index(['José Luis Martínez Izquierdo', 'Rosa Díaz Díaz',
#        'Javier García Sánchez', 'Carmen López Pinzón', 'Marisa López Collado',
#        'Antonio Ruiz Cruz', 'Antonio Fernández Ocaña', 'Pilar Martín González',
#        'Pedro Gálvez Tenorio', 'Santiago Reillo Manzano',
#        'Macarena Álvarez Luna', 'José María de la Guía Sanz',
#        'Miguel Angel Cuadrado Gutiérrez', 'Carolina Rubio Moreno'],
#       dtype='object', name='nombre')

# %%
csv.dtypes
# Out:
# edad            int64
# sexo           object
# peso          float64
# altura         object
# colesterol    float64
# dtype: object

# %%
## Muestra las primeras filas del dataframe
csv.head(3)
# Out:
#                               edad sexo  peso altura  colesterol
# nombre
# José Luis Martínez Izquierdo    18    H  85.0   1,79       182.0
# Rosa Díaz Díaz                  32    M  65.0   1,73       232.0
# Javier García Sánchez           24    H   NaN   1,81       191.0

# %%
## Muestra las ultimas filas del dataframe
csv.tail(3)
# Out:
#                                  edad sexo   peso altura  colesterol
# nombre
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0

# %%
excel = csv.rename(columns={'nombre':'Nombre y Apellido', 'altura': 'Altura', 'edad': 'Edad', 'sexo': 'Sexo', 'peso': 'Peso'}, index = {0:1000, 1:1001, 2: 1002})

# %%
excel
# Out:
#                                  Edad Sexo   Peso Altura  colesterol
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0

# %%
excel.reindex(index = [4,1001,1002], columns=['Nombre y Apellido', 'Tensión', 'colesterol'])
# Out:
#         Nombre y Apellido  Tensión  colesterol
# nombre
# 4                     NaN      NaN         NaN
# 1001                  NaN      NaN         NaN
# 1002                  NaN      NaN         NaN

# %%
excel
# Out:
#                                  Edad Sexo   Peso Altura  colesterol
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0

# %%
excel.iloc[0:5,2]
# Out:
# nombre
# José Luis Martínez Izquierdo    85.0
# Rosa Díaz Díaz                  65.0
# Javier García Sánchez            NaN
# Carmen López Pinzón             65.0
# Marisa López Collado            51.0
# Name: Peso, dtype: float64

# %%
excel.dropna()
# Out:
#                                  Edad Sexo   Peso Altura  colesterol
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0

# %%
(excel[(excel['Sexo']=='H') & (excel['colesterol'] > 220)])
# Out:
#                          Edad Sexo  Peso Altura  colesterol
# nombre
# Antonio Ruiz Cruz          68    H  66.0   1,74       249.0
# Antonio Fernández Ocaña    51    H  62.0   1,72       276.0
# Pedro Gálvez Tenorio       35    H  90.0   1,94       241.0
# Santiago Reillo Manzano    46    H  75.0   1,85       280.0

# %%
excel.sort_values('colesterol',ascending= False )
# Out:
#                                  Edad Sexo   Peso Altura  colesterol
# nombre
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Pilar Martín González              22    M   60.0   1,66         NaN

# %%
excel.sort_index(ascending=False)
# Out:
#                                  Edad Sexo   Peso Altura  colesterol
# nombre
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0

# %%
excel.iloc[0:5]
# Out:
#                               Edad Sexo  Peso Altura  colesterol
# nombre
# José Luis Martínez Izquierdo    18    H  85.0   1,79       182.0
# Rosa Díaz Díaz                  32    M  65.0   1,73       232.0
# Javier García Sánchez           24    H   NaN   1,81       191.0
# Carmen López Pinzón             35    M  65.0   1,70       200.0
# Marisa López Collado            46    M  51.0   1,58       148.0

# %%
excel.iloc[1]
# Out:
# Edad             32
# Sexo              M
# Peso           65.0
# Altura         1,73
# colesterol    232.0
# Name: Rosa Díaz Díaz, dtype: object

# %%
## loc
excel.loc['Rosa Díaz Díaz'] ## error porque ninguna se llama '2'
# Out:
# Edad             32
# Sexo              M
# Peso           65.0
# Altura         1,73
# colesterol    232.0
# Name: Rosa Díaz Díaz, dtype: object

# %%
excel.loc['Javier García Sánchez']
# Out:
# Edad             24
# Sexo              H
# Peso            NaN
# Altura         1,81
# colesterol    191.0
# Name: Javier García Sánchez, dtype: object

# %%
excel['Peso']
# Out:
# nombre
# José Luis Martínez Izquierdo        85.0
# Rosa Díaz Díaz                      65.0
# Javier García Sánchez                NaN
# Carmen López Pinzón                 65.0
# Marisa López Collado                51.0
# Antonio Ruiz Cruz                   66.0
# Antonio Fernández Ocaña             62.0
# Pilar Martín González               60.0
# Pedro Gálvez Tenorio                90.0
# Santiago Reillo Manzano             75.0
# Macarena Álvarez Luna               55.0
# José María de la Guía Sanz          78.0
# Miguel Angel Cuadrado Gutiérrez    109.0
# Carolina Rubio Moreno               61.0
# Name: Peso, dtype: float64

# %%
## le pasamos una lista de valores
excel['nueva columna'] = [2,5,2,5,6,5,8,9,8,9,2,1,2,None]

# %%
excel
# Out:
#                                  Edad Sexo   Peso Altura  colesterol  \
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0
#
#                                  nueva columna
# nombre
# José Luis Martínez Izquierdo               2.0
# Rosa Díaz Díaz                             5.0
# Javier García Sánchez                      2.0
# Carmen López Pinzón                        5.0
# Marisa López Collado                       6.0
# Antonio Ruiz Cruz                          5.0
# Antonio Fernández Ocaña                    8.0
# Pilar Martín González                      9.0
# Pedro Gálvez Tenorio                       8.0
# Santiago Reillo Manzano                    9.0
# Macarena Álvarez Luna                      2.0
# José María de la Guía Sanz                 1.0
# Miguel Angel Cuadrado Gutiérrez            2.0
# Carolina Rubio Moreno                      NaN

# %%
excel['diabetes'] = pd.Series([None,None,None,True, True, False, False, False])

# %%
excel
# Out:
#                                  Edad Sexo   Peso Altura  colesterol  \
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0
#
#                                  nueva columna diabetes
# nombre
# José Luis Martínez Izquierdo               2.0      NaN
# Rosa Díaz Díaz                             5.0      NaN
# Javier García Sánchez                      2.0      NaN
# Carmen López Pinzón                        5.0      NaN
# Marisa López Collado                       6.0      NaN
# Antonio Ruiz Cruz                          5.0      NaN
# Antonio Fernández Ocaña                    8.0      NaN
# Pilar Martín González                      9.0      NaN
# Pedro Gálvez Tenorio                       8.0      NaN
# Santiago Reillo Manzano                    9.0      NaN
# Macarena Álvarez Luna                      2.0      NaN
# José María de la Guía Sanz                 1.0      NaN
# Miguel Angel Cuadrado Gutiérrez            2.0      NaN
# Carolina Rubio Moreno                      NaN      NaN

# %%
excel['Altura']*100
# Out:
# nombre
# José Luis Martínez Izquierdo       1,791,791,791,791,791,791,791,791,791,791,791,...
# Rosa Díaz Díaz                     1,731,731,731,731,731,731,731,731,731,731,731,...
# Javier García Sánchez              1,811,811,811,811,811,811,811,811,811,811,811,...
# Carmen López Pinzón                1,701,701,701,701,701,701,701,701,701,701,701,...
# Marisa López Collado               1,581,581,581,581,581,581,581,581,581,581,581,...
# Antonio Ruiz Cruz                  1,741,741,741,741,741,741,741,741,741,741,741,...
# Antonio Fernández Ocaña            1,721,721,721,721,721,721,721,721,721,721,721,...
# Pilar Martín González              1,661,661,661,661,661,661,661,661,661,661,661,...
# Pedro Gálvez Tenorio               1,941,941,941,941,941,941,941,941,941,941,941,...
# Santiago Reillo Manzano            1,851,851,851,851,851,851,851,851,851,851,851,...
# Macarena Álvarez Luna              1,621,621,621,621,621,621,621,621,621,621,621,...
# José María de la Guía Sanz         1,871,871,871,871,871,871,871,871,871,871,871,...
# Miguel Angel Cuadrado Gutiérrez    1,981,981,981,981,981,981,981,981,981,981,981,...
# Carolina Rubio Moreno              1,771,771,771,771,771,771,771,771,771,771,771,...
# Name: Altura, dtype: object

# %%
excel
# Out:
#                                  Edad Sexo   Peso Altura  colesterol  \
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0
#
#                                  nueva columna diabetes
# nombre
# José Luis Martínez Izquierdo               2.0      NaN
# Rosa Díaz Díaz                             5.0      NaN
# Javier García Sánchez                      2.0      NaN
# Carmen López Pinzón                        5.0      NaN
# Marisa López Collado                       6.0      NaN
# Antonio Ruiz Cruz                          5.0      NaN
# Antonio Fernández Ocaña                    8.0      NaN
# Pilar Martín González                      9.0      NaN
# Pedro Gálvez Tenorio                       8.0      NaN
# Santiago Reillo Manzano                    9.0      NaN
# Macarena Álvarez Luna                      2.0      NaN
# José María de la Guía Sanz                 1.0      NaN
# Miguel Angel Cuadrado Gutiérrez            2.0      NaN
# Carolina Rubio Moreno                      NaN      NaN

# %%
excel['Altura_cm']=excel['Altura']*100
excel
# Out:
#                                  Edad Sexo   Peso Altura  colesterol  \
# nombre
# José Luis Martínez Izquierdo       18    H   85.0   1,79       182.0
# Rosa Díaz Díaz                     32    M   65.0   1,73       232.0
# Javier García Sánchez              24    H    NaN   1,81       191.0
# Carmen López Pinzón                35    M   65.0   1,70       200.0
# Marisa López Collado               46    M   51.0   1,58       148.0
# Antonio Ruiz Cruz                  68    H   66.0   1,74       249.0
# Antonio Fernández Ocaña            51    H   62.0   1,72       276.0
# Pilar Martín González              22    M   60.0   1,66         NaN
# Pedro Gálvez Tenorio               35    H   90.0   1,94       241.0
# Santiago Reillo Manzano            46    H   75.0   1,85       280.0
# Macarena Álvarez Luna              53    M   55.0   1,62       262.0
# José María de la Guía Sanz         58    H   78.0   1,87       198.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0   1,98       210.0
# Carolina Rubio Moreno              20    M   61.0   1,77       194.0
#
#                                  nueva columna diabetes  \
# nombre
# José Luis Martínez Izquierdo               2.0      NaN
# Rosa Díaz Díaz                             5.0      NaN
# Javier García Sánchez                      2.0      NaN
# Carmen López Pinzón                        5.0      NaN
# Marisa López Collado                       6.0      NaN
# Antonio Ruiz Cruz                          5.0      NaN
# Antonio Fernández Ocaña                    8.0      NaN
# Pilar Martín González                      9.0      NaN
# Pedro Gálvez Tenorio                       8.0      NaN
# Santiago Reillo Manzano                    9.0      NaN
# Macarena Álvarez Luna                      2.0      NaN
# José María de la Guía Sanz                 1.0      NaN
# Miguel Angel Cuadrado Gutiérrez            2.0      NaN
# Carolina Rubio Moreno                      NaN      NaN
#
#                                                                          Altura_cm
# nombre
# José Luis Martínez Izquierdo     1,791,791,791,791,791,791,791,791,791,791,791,...
# Rosa Díaz Díaz                   1,731,731,731,731,731,731,731,731,731,731,731,...
# Javier García Sánchez            1,811,811,811,811,811,811,811,811,811,811,811,...
# Carmen López Pinzón              1,701,701,701,701,701,701,701,701,701,701,701,...
# Marisa López Collado             1,581,581,581,581,581,581,581,581,581,581,581,...
# Antonio Ruiz Cruz                1,741,741,741,741,741,741,741,741,741,741,741,...
# Antonio Fernández Ocaña          1,721,721,721,721,721,721,721,721,721,721,721,...
# Pilar Martín González            1,661,661,661,661,661,661,661,661,661,661,661,...
# Pedro Gálvez Tenorio             1,941,941,941,941,941,941,941,941,941,941,941,...
# Santiago Reillo Manzano          1,851,851,851,851,851,851,851,851,851,851,851,...
# Macarena Álvarez Luna            1,621,621,621,621,621,621,621,621,621,621,621,...
# José María de la Guía Sanz       1,871,871,871,871,871,871,871,871,871,871,871,...
# Miguel Angel Cuadrado Gutiérrez  1,981,981,981,981,981,981,981,981,981,981,981,...
# Carolina Rubio Moreno            1,771,771,771,771,771,771,771,771,771,771,771,...

# %%
excel.drop(columns='Altura')
# Out:
#                                  Edad Sexo   Peso  colesterol  nueva columna  \
# nombre
# José Luis Martínez Izquierdo       18    H   85.0       182.0            2.0
# Rosa Díaz Díaz                     32    M   65.0       232.0            5.0
# Javier García Sánchez              24    H    NaN       191.0            2.0
# Carmen López Pinzón                35    M   65.0       200.0            5.0
# Marisa López Collado               46    M   51.0       148.0            6.0
# Antonio Ruiz Cruz                  68    H   66.0       249.0            5.0
# Antonio Fernández Ocaña            51    H   62.0       276.0            8.0
# Pilar Martín González              22    M   60.0         NaN            9.0
# Pedro Gálvez Tenorio               35    H   90.0       241.0            8.0
# Santiago Reillo Manzano            46    H   75.0       280.0            9.0
# Macarena Álvarez Luna              53    M   55.0       262.0            2.0
# José María de la Guía Sanz         58    H   78.0       198.0            1.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0       210.0            2.0
# Carolina Rubio Moreno              20    M   61.0       194.0            NaN
#
#                                 diabetes  \
# nombre
# José Luis Martínez Izquierdo         NaN
# Rosa Díaz Díaz                       NaN
# Javier García Sánchez                NaN
# Carmen López Pinzón                  NaN
# Marisa López Collado                 NaN
# Antonio Ruiz Cruz                    NaN
# Antonio Fernández Ocaña              NaN
# Pilar Martín González                NaN
# Pedro Gálvez Tenorio                 NaN
# Santiago Reillo Manzano              NaN
# Macarena Álvarez Luna                NaN
# José María de la Guía Sanz           NaN
# Miguel Angel Cuadrado Gutiérrez      NaN
# Carolina Rubio Moreno                NaN
#
#                                                                          Altura_cm
# nombre
# José Luis Martínez Izquierdo     1,791,791,791,791,791,791,791,791,791,791,791,...
# Rosa Díaz Díaz                   1,731,731,731,731,731,731,731,731,731,731,731,...
# Javier García Sánchez            1,811,811,811,811,811,811,811,811,811,811,811,...
# Carmen López Pinzón              1,701,701,701,701,701,701,701,701,701,701,701,...
# Marisa López Collado             1,581,581,581,581,581,581,581,581,581,581,581,...
# Antonio Ruiz Cruz                1,741,741,741,741,741,741,741,741,741,741,741,...
# Antonio Fernández Ocaña          1,721,721,721,721,721,721,721,721,721,721,721,...
# Pilar Martín González            1,661,661,661,661,661,661,661,661,661,661,661,...
# Pedro Gálvez Tenorio             1,941,941,941,941,941,941,941,941,941,941,941,...
# Santiago Reillo Manzano          1,851,851,851,851,851,851,851,851,851,851,851,...
# Macarena Álvarez Luna            1,621,621,621,621,621,621,621,621,621,621,621,...
# José María de la Guía Sanz       1,871,871,871,871,871,871,871,871,871,871,871,...
# Miguel Angel Cuadrado Gutiérrez  1,981,981,981,981,981,981,981,981,981,981,981,...
# Carolina Rubio Moreno            1,771,771,771,771,771,771,771,771,771,771,771,...

# %%
excel['Peso']/2
# Out:
# nombre
# José Luis Martínez Izquierdo       42.5
# Rosa Díaz Díaz                     32.5
# Javier García Sánchez               NaN
# Carmen López Pinzón                32.5
# Marisa López Collado               25.5
# Antonio Ruiz Cruz                  33.0
# Antonio Fernández Ocaña            31.0
# Pilar Martín González              30.0
# Pedro Gálvez Tenorio               45.0
# Santiago Reillo Manzano            37.5
# Macarena Álvarez Luna              27.5
# José María de la Guía Sanz         39.0
# Miguel Angel Cuadrado Gutiérrez    54.5
# Carolina Rubio Moreno              30.5
# Name: Peso, dtype: float64

# %%
df = pd.DataFrame({'Name': ['María', 'Carlos', 'Carmen'], 'Nacimiento':['05-03-2000', '20-05-2001', '10-12-1999']})
df
# Out:
#      Name  Nacimiento
# 0   María  05-03-2000
# 1  Carlos  20-05-2001
# 2  Carmen  10-12-1999

# %%
df = pd.to_datetime(df.Nacimiento, format = '%d-%m-%Y')
df
# Out:
# 0   2000-03-05
# 1   2001-05-20
# 2   1999-12-10
# Name: Nacimiento, dtype: datetime64[ns]

# %%
excel.count()
# Out:
# Edad             14
# Sexo             14
# Peso             13
# Altura           14
# colesterol       13
# nueva columna    13
# diabetes          0
# Altura_cm        14
# dtype: int64

# %%
excel.sum()
# Out:
# Edad                                                           535
# Sexo                                                HMHMMHHMHHMHHM
# Peso                                                         922.0
# Altura           1,791,731,811,701,581,741,721,661,941,851,621,...
# colesterol                                                  2863.0
# nueva columna                                                 64.0
# diabetes                                                         0
# Altura_cm        1,791,791,791,791,791,791,791,791,791,791,791,...
# dtype: object

# %%
excel['Peso'].sum()
# Out:
# 922.0

# %%
excel.cumsum()
# Out:
#                                  Edad            Sexo   Peso  \
# nombre
# José Luis Martínez Izquierdo       18               H   85.0
# Rosa Díaz Díaz                     50              HM  150.0
# Javier García Sánchez              74             HMH    NaN
# Carmen López Pinzón               109            HMHM  215.0
# Marisa López Collado              155           HMHMM  266.0
# Antonio Ruiz Cruz                 223          HMHMMH  332.0
# Antonio Fernández Ocaña           274         HMHMMHH  394.0
# Pilar Martín González             296        HMHMMHHM  454.0
# Pedro Gálvez Tenorio              331       HMHMMHHMH  544.0
# Santiago Reillo Manzano           377      HMHMMHHMHH  619.0
# Macarena Álvarez Luna             430     HMHMMHHMHHM  674.0
# José María de la Guía Sanz        488    HMHMMHHMHHMH  752.0
# Miguel Angel Cuadrado Gutiérrez   515   HMHMMHHMHHMHH  861.0
# Carolina Rubio Moreno             535  HMHMMHHMHHMHHM  922.0
#
#                                                                             Altura  \
# nombre
# José Luis Martínez Izquierdo                                                  1,79
# Rosa Díaz Díaz                                                            1,791,73
# Javier García Sánchez                                                 1,791,731,81
# Carmen López Pinzón                                               1,791,731,811,70
# Marisa López Collado                                          1,791,731,811,701,58
# Antonio Ruiz Cruz                                         1,791,731,811,701,581,74
# Antonio Fernández Ocaña                               1,791,731,811,701,581,741,72
# Pilar Martín González                             1,791,731,811,701,581,741,721,66
# Pedro Gálvez Tenorio                          1,791,731,811,701,581,741,721,661,94
# Santiago Reillo Manzano                   1,791,731,811,701,581,741,721,661,941,85
# Macarena Álvarez Luna                 1,791,731,811,701,581,741,721,661,941,851,62
# José María de la Guía Sanz        1,791,731,811,701,581,741,721,661,941,851,621,87
# Miguel Angel Cuadrado Gutiérrez  1,791,731,811,701,581,741,721,661,941,851,621,...
# Carolina Rubio Moreno            1,791,731,811,701,581,741,721,661,941,851,621,...
#
#                                  colesterol  nueva columna diabetes  \
# nombre
# José Luis Martínez Izquierdo          182.0            2.0      NaN
# Rosa Díaz Díaz                        414.0            7.0      NaN
# Javier García Sánchez                 605.0            9.0      NaN
# Carmen López Pinzón                   805.0           14.0      NaN
# Marisa López Collado                  953.0           20.0      NaN
# Antonio Ruiz Cruz                    1202.0           25.0      NaN
# Antonio Fernández Ocaña              1478.0           33.0      NaN
# Pilar Martín González                   NaN           42.0      NaN
# Pedro Gálvez Tenorio                 1719.0           50.0      NaN
# Santiago Reillo Manzano              1999.0           59.0      NaN
# Macarena Álvarez Luna                2261.0           61.0      NaN
# José María de la Guía Sanz           2459.0           62.0      NaN
# Miguel Angel Cuadrado Gutiérrez      2669.0           64.0      NaN
# Carolina Rubio Moreno                2863.0            NaN      NaN
#
#                                                                          Altura_cm
# nombre
# José Luis Martínez Izquierdo     1,791,791,791,791,791,791,791,791,791,791,791,...
# Rosa Díaz Díaz                   1,791,791,791,791,791,791,791,791,791,791,791,...
# Javier García Sánchez            1,791,791,791,791,791,791,791,791,791,791,791,...
# Carmen López Pinzón              1,791,791,791,791,791,791,791,791,791,791,791,...
# Marisa López Collado             1,791,791,791,791,791,791,791,791,791,791,791,...
# Antonio Ruiz Cruz                1,791,791,791,791,791,791,791,791,791,791,791,...
# Antonio Fernández Ocaña          1,791,791,791,791,791,791,791,791,791,791,791,...
# Pilar Martín González            1,791,791,791,791,791,791,791,791,791,791,791,...
# Pedro Gálvez Tenorio             1,791,791,791,791,791,791,791,791,791,791,791,...
# Santiago Reillo Manzano          1,791,791,791,791,791,791,791,791,791,791,791,...
# Macarena Álvarez Luna            1,791,791,791,791,791,791,791,791,791,791,791,...
# José María de la Guía Sanz       1,791,791,791,791,791,791,791,791,791,791,791,...
# Miguel Angel Cuadrado Gutiérrez  1,791,791,791,791,791,791,791,791,791,791,791,...
# Carolina Rubio Moreno            1,791,791,791,791,791,791,791,791,791,791,791,...

# %%
excel.min()
# Out:
# Edad                                                            18
# Sexo                                                             H
# Peso                                                          51.0
# Altura                                                        1,58
# colesterol                                                   148.0
# nueva columna                                                  1.0
# diabetes                                                      None
# Altura_cm        1,581,581,581,581,581,581,581,581,581,581,581,...
# dtype: object

# %%
excel.max()
# Out:
# Edad                                                            68
# Sexo                                                             M
# Peso                                                         109.0
# Altura                                                        1,98
# colesterol                                                   280.0
# nueva columna                                                  9.0
# diabetes                                                      None
# Altura_cm        1,981,981,981,981,981,981,981,981,981,981,981,...
# dtype: object

# %%
excel.std()
# Out:
# C:\Users\salas\AppData\Local\Temp\ipykernel_8172\946026668.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   excel.std()
# Edad             15.621379
# Peso             16.126901
# colesterol       39.847948
# nueva columna     2.928638
# diabetes               NaN
# dtype: float64

# %%
excel.mean()
# Out:
# C:\Users\salas\AppData\Local\Temp\ipykernel_8172\158354169.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   excel.mean()
# Edad              38.214286
# Peso              70.923077
# colesterol       220.230769
# nueva columna      4.923077
# diabetes                NaN
# dtype: float64

# %%
excel.describe()
# Out:
#             Edad        Peso  colesterol  nueva columna
# count  14.000000   13.000000   13.000000      13.000000
# mean   38.214286   70.923077  220.230769       4.923077
# std    15.621379   16.126901   39.847948       2.928638
# min    18.000000   51.000000  148.000000       1.000000
# 25%    24.750000   61.000000  194.000000       2.000000
# 50%    35.000000   65.000000  210.000000       5.000000
# 75%    49.750000   78.000000  249.000000       8.000000
# max    68.000000  109.000000  280.000000       9.000000

# %%
excel.pop('Altura')
# Out:
# nombre
# José Luis Martínez Izquierdo       1,79
# Rosa Díaz Díaz                     1,73
# Javier García Sánchez              1,81
# Carmen López Pinzón                1,70
# Marisa López Collado               1,58
# Antonio Ruiz Cruz                  1,74
# Antonio Fernández Ocaña            1,72
# Pilar Martín González              1,66
# Pedro Gálvez Tenorio               1,94
# Santiago Reillo Manzano            1,85
# Macarena Álvarez Luna              1,62
# José María de la Guía Sanz         1,87
# Miguel Angel Cuadrado Gutiérrez    1,98
# Carolina Rubio Moreno              1,77
# Name: Altura, dtype: object

# %%
excel.pop('Altura_cm')
# Out:
# nombre
# José Luis Martínez Izquierdo       1,791,791,791,791,791,791,791,791,791,791,791,...
# Rosa Díaz Díaz                     1,731,731,731,731,731,731,731,731,731,731,731,...
# Javier García Sánchez              1,811,811,811,811,811,811,811,811,811,811,811,...
# Carmen López Pinzón                1,701,701,701,701,701,701,701,701,701,701,701,...
# Marisa López Collado               1,581,581,581,581,581,581,581,581,581,581,581,...
# Antonio Ruiz Cruz                  1,741,741,741,741,741,741,741,741,741,741,741,...
# Antonio Fernández Ocaña            1,721,721,721,721,721,721,721,721,721,721,721,...
# Pilar Martín González              1,661,661,661,661,661,661,661,661,661,661,661,...
# Pedro Gálvez Tenorio               1,941,941,941,941,941,941,941,941,941,941,941,...
# Santiago Reillo Manzano            1,851,851,851,851,851,851,851,851,851,851,851,...
# Macarena Álvarez Luna              1,621,621,621,621,621,621,621,621,621,621,621,...
# José María de la Guía Sanz         1,871,871,871,871,871,871,871,871,871,871,871,...
# Miguel Angel Cuadrado Gutiérrez    1,981,981,981,981,981,981,981,981,981,981,981,...
# Carolina Rubio Moreno              1,771,771,771,771,771,771,771,771,771,771,771,...
# Name: Altura_cm, dtype: object

# %%
excel
# Out:
#                                  Edad Sexo   Peso  colesterol  nueva columna  \
# nombre
# José Luis Martínez Izquierdo       18    H   85.0       182.0            2.0
# Rosa Díaz Díaz                     32    M   65.0       232.0            5.0
# Javier García Sánchez              24    H    NaN       191.0            2.0
# Carmen López Pinzón                35    M   65.0       200.0            5.0
# Marisa López Collado               46    M   51.0       148.0            6.0
# Antonio Ruiz Cruz                  68    H   66.0       249.0            5.0
# Antonio Fernández Ocaña            51    H   62.0       276.0            8.0
# Pilar Martín González              22    M   60.0         NaN            9.0
# Pedro Gálvez Tenorio               35    H   90.0       241.0            8.0
# Santiago Reillo Manzano            46    H   75.0       280.0            9.0
# Macarena Álvarez Luna              53    M   55.0       262.0            2.0
# José María de la Guía Sanz         58    H   78.0       198.0            1.0
# Miguel Angel Cuadrado Gutiérrez    27    H  109.0       210.0            2.0
# Carolina Rubio Moreno              20    M   61.0       194.0            NaN
#
#                                 diabetes
# nombre
# José Luis Martínez Izquierdo         NaN
# Rosa Díaz Díaz                       NaN
# Javier García Sánchez                NaN
# Carmen López Pinzón                  NaN
# Marisa López Collado                 NaN
# Antonio Ruiz Cruz                    NaN
# Antonio Fernández Ocaña              NaN
# Pilar Martín González                NaN
# Pedro Gálvez Tenorio                 NaN
# Santiago Reillo Manzano              NaN
# Macarena Álvarez Luna                NaN
# José María de la Guía Sanz           NaN
# Miguel Angel Cuadrado Gutiérrez      NaN
# Carolina Rubio Moreno                NaN

# %%
excel.append(pd.Series(['Carlos Rivas', 28, 'H', 89.0, 1.78, 245.0], index=['Nombre y Apellido','Edad','Sexo','Peso','Altura','colesterol']), ignore_index=True)
# Out:
# C:\Users\salas\AppData\Local\Temp\ipykernel_8172\197560071.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   excel.append(pd.Series(['Carlos Rivas', 28, 'H', 89.0, 1.78, 245.0], index=['Nombre y Apellido','Edad','Sexo','Peso','Altura','colesterol']), ignore_index=True)
#     Edad Sexo   Peso  colesterol  nueva columna diabetes  Altura  \
# 0     18    H   85.0       182.0            2.0      NaN     NaN
# 1     32    M   65.0       232.0            5.0      NaN     NaN
# 2     24    H    NaN       191.0            2.0      NaN     NaN
# 3     35    M   65.0       200.0            5.0      NaN     NaN
# 4     46    M   51.0       148.0            6.0      NaN     NaN
# 5     68    H   66.0       249.0            5.0      NaN     NaN
# 6     51    H   62.0       276.0            8.0      NaN     NaN
# 7     22    M   60.0         NaN            9.0      NaN     NaN
# 8     35    H   90.0       241.0            8.0      NaN     NaN
# 9     46    H   75.0       280.0            9.0      NaN     NaN
# 10    53    M   55.0       262.0            2.0      NaN     NaN
# 11    58    H   78.0       198.0            1.0      NaN     NaN
# 12    27    H  109.0       210.0            2.0      NaN     NaN
# 13    20    M   61.0       194.0            NaN      NaN     NaN
# 14    28    H   89.0       245.0            NaN      NaN    1.78
#
#    Nombre y Apellido
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14      Carlos Rivas

# %%
excel.drop(index=[1000,1001])
excel
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8172\2600971603.py in <module>
# ----> 1 excel.drop(index=[1000,1001])
#       2 excel
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# c:\Users\salas\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: '[1000, 1001] not found in axis'

# %%
(excel[(excel['Sexo']=='H') & (excel['colesterol'] > 260)])

# %%
excel.sort_values('Edad', ascending=False)

# %%
excel.sort_values('colesterol', ascending=False)

# %%
excel.dropna()

# %%
print('a')

# %%
a = 'd'
d = 0
a [ccccc]
